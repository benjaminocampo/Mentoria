# %% [markdown]
# # DiploDatos 2021
#
#
# ### Categorización de publicaciones de productos realizadas en Mercado Libre

# %% [markdown]
# ### 02 - Análisis y Curación

# %% [markdown]
# #### Condiciones generales que aplican a todos los prácticos:
#    - Las notebooks tienen que ser 100% reproducibles, es decir al ejecutar las celdas tal cuál como se entrega la notebook se deben obtener los mismos resultados sin errores.
#    - Código legible, haciendo buen uso de las celdas de la notebook y en lo posible seguir estándares de código para Python (https://www.python.org/dev/peps/pep-0008/).
#    - Utilizar celdas tipo "Markdown" para ir guiando el análisis.
#    - Limpiar el output de las celdas antes de entregar el notebook (ir a Kernel --> Restart Kernel and Clear All Ouputs).
#    - Incluir conclusiones del análisis que se hizo en la sección "Conclusiones". Tratar de aportar valor en esta sección, ser creativo!

# %% [markdown]
# ## 1. Consignas

# %% [markdown]
# #### Sección C: Label Encoding

# %% [markdown]
# 1. Utilizar método *LabelEncoder()* de sklearn:
#
# - https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelEncoder.html

# %% [markdown]
# #### Sección D: Word Embeddings
#
# Generar los word embeddings correspondientes, de las siguientes 2 formas:
#
# 1. Custom Word Embeddings
# 2. Loading Pretrained Word Embeddings (opcional)
#
# En ambos puntos el objetivos final es llegar a crear la embedding layer de keras:
#
# - https://keras.io/api/layers/core_layers/embedding/

# %% [markdown]
# ## 3. Conclusiones
#
# #### Material de ayuda para el desarrollo de este práctico:
#
# 1. Implementación en keras de word embeddings: https://stackabuse.com/python-for-nlp-word-embeddings-for-deep-learning-in-keras
# 2. Como utilizar pre-trained word embeddings en Keras: https://keras.io/examples/nlp/pretrained_word_embeddings/
# 3. Word Embeddings: https://jalammar.github.io/illustrated-word2vec/
# 3. Curso de procesamiento del lenguaje natural con Keras: https://www.coursera.org/learn/natural-language-processing-tensorflow/home/welcome

# %% [markdown]
# ## 2. Código y análisis

# %% [markdown]
# Imports necesarios

# %%
# !pip3 install unidecode
# Out:
# Collecting unidecode
#   Downloading https://files.pythonhosted.org/packages/9e/25/723487ca2a52ebcee88a34d7d1f5a4b80b793f179ee0f62d5371938dfa01/Unidecode-1.2.0-py2.py3-none-any.whl (241kB)
#      |████████████████████████████████| 245kB 6.4MB/s
# Installing collected packages: unidecode
# Successfully installed unidecode-1.2.0

# %%
import pandas as pd
import numpy
from unidecode import unidecode
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download("stopwords")
nltk.download('punkt')

stopwords = \
    set(nltk.corpus.stopwords.words("spanish")) | \
    set(nltk.corpus.stopwords.words("portuguese"))

# Función que hace el Unidecode
def uni_deco(s: str):
    return unidecode(s)

def remove_unimportant_words(s):
    """
    Removes from the string @s all the stopwords, digits, and special chars
    """
    special_chars = "-.+,[@_!#$%^&*()<>?/\|}{~:]"
    digits = "0123456789"
    invalid_chars = special_chars + digits

    reduced_title = ''.join(c for c in s if not c in invalid_chars)
    
    reduced_title = ' '.join(
        w.lower() for w in word_tokenize(reduced_title)
        if not w.lower() in stopwords
    )
    return reduced_title


# Si después vamos a quitar los stopwords, quizás habría que directamente 
# quitar las contracciones en lugar de reemplazarlas.

def contracciones(s: str):
    title=s
    dict_contracciones={" c/u ": "cada uno", " p/":"para"," c/":"con"}
    for key,value in dict_contracciones.items():
        title=title.split(key)
        title=value.join(title)
    return title

#print(unidecode(u"\u5317\u4EB0"))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Lectura del Dataset reducido
URL = "https://www.famaf.unc.edu.ar/~nocampo043/ml_challenge2019_dataset.csv"
df = pd.read_csv(URL)

# %%
df.head()
# Out:
#                                                title  ...           category
# 0                          Galoneira Semi Industrial  ...    SEWING_MACHINES
# 1                Máquina De Coser Brother Industrial  ...    SEWING_MACHINES
# 2  Teclado Casio Wk-240 76 Teclas Profissional St...  ...  MUSICAL_KEYBOARDS
# 3                Heladera Gafa 380 Impecable Urgente  ...      REFRIGERATORS
# 4  Butaca  6 Cuotas Sin Interes!! Para Auto Bebes...  ...     BABY_CAR_SEATS
#
# [5 rows x 4 columns]

# %% [markdown]
# Lectura de dataset reducido

# %% [markdown]
# #### Sección A:  Limpieza de texto / Preprocessing
#
# Tener en cuenta lo siguiente:
#
# 1. Unidecode
#
# 2. Pasar a minúsculas
#
# 3. Limpiar números
#
# 4. Limpiar símbolos --> '!¡"@$%&*,.:;<=>?@[\\]^_`{|}~\t\n'
#
# 5. Limpiar caracteres que sueles usarse como espacios --> '+()-\''
#
# 6. Reemplazar "contracciones", por ejemplo:
#         -'c/u ' por 'cada uno'
#         -'c/' por 'con'
#         -'p/' por 'para'
#
#
# 7. Etc! Pueden sumar mas steps

# %% [markdown]
# ***A.1 Unidecode***

# %%
df.title.apply(uni_deco).apply(contracciones).apply(remove_unimportant_words)
# Out:
# 0                                 galoneira semi industrial
# 1                          maquina coser brother industrial
# 2             teclado casio wk teclas profissional standard
# 3                           heladera gafa impecable urgente
# 4                     butaca cuotas interes auto bebesit kg
#                                 ...
# 646755                                   thank you malbec x
# 646756    cachorros jack rusell terrier corto ultimo dis...
# 646757    colchao box casal castor vitagel euro one face xx
# 646758                                maquina cortar starex
# 646759           trimmer detailer wahl kit tijeras stylecut
# Name: title, Length: 646760, dtype: object

# %%
df[df.title.apply(lambda s: "/" in s)][df.language=="portuguese"]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#                                                     title  ...         category
# 74      Cartão Evo Select Samsung Microsd 128gb U3 4k ...  ...     MEMORY_CARDS
# 82      Cartão Sdhc Sandisk Extreme Classe 10  32gb 90...  ...     MEMORY_CARDS
# 93                  Patins Rollerblade K2 Semi Novo 42/43  ...    ROLLER_SKATES
# 124     Furadeira De Impacto Mondial 3/8  550 Watts Fi-09  ...  ELECTRIC_DRILLS
# 142     Máquina De Cortar Cabelo/barba Cabeleireiro Ph...  ...    HAIR_CLIPPERS
# ...                                                   ...  ...              ...
# 646663  Patins 3 Rodas Azul Ajust. 26/29 Kit Proteção ...  ...    ROLLER_SKATES
# 646687  Cartão Memória Micro Sd 4gb Lacrado Original C...  ...     MEMORY_CARDS
# 646693  Respiração 3d Almofada Assento De Malha / Almo...  ...   BABY_CAR_SEATS
# 646704  Furadeira De Impacto Sdh600-br 1/2  600w - Sta...  ...  ELECTRIC_DRILLS
# 646749  Kit C/ 30 Cartão Sdhc Ultra 80mb/s Classe 10 1...  ...     MEMORY_CARDS
#
# [42097 rows x 4 columns]

# %%
df.loc[142].title
# Out:
# 'Máquina De Cortar Cabelo/barba Cabeleireiro Philips Hc3410'

# %% [markdown]
# #### Sección B: Tokenización & Secuencias
#
# 1. Utilizar métodos *fit_on_texts()*, *texts_to_sequences()* y *pad_sequences()*:
#
# - https://keras.io/api/preprocessing/text/#tokenizer-class
#
# - https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/sequence/pad_sequences

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

# %%
tokenizer = Tokenizer(lower=True)#pruebas
tok=tokenizer.fit_on_texts(df.title) #pruebas

# %%
X = tokenizer.texts_to_sequences(df.title) #pruebas

# %%
dictionary=dict()
rev_dictionary = dict()
for key, value in tokenizer.word_index.items():
    dictionary[value] = key
    rev_dictionary[key] = value

# %%
tokenizer.word_index.items()
# Out:
# dict_items([('de', 1), ('para', 2), ('2', 3), ('1', 4), ('com', 5), ('cocina', 6), ('4', 7), ('con', 8), ('kit', 9), ('3', 10), ('teclado', 11), ('a', 12), ('maquina', 13), ('e', 14), ('máquina', 15), ('micro', 16), ('y', 17), ('c', 18), ('sd', 19), ('heladera', 20), ('inox', 21), ('jaqueta', 22), ('colchão', 23), ('patins', 24), ('carrinho', 25), ('calça', 26), ('bebê', 27), ('5', 28), ('cafetera', 29), ('10', 30), ('jeans', 31), ('taladro', 32), ('x', 33), ('furadeira', 34), ('auto', 35), ('short', 36), ('cafeteira', 37), ('parede', 38), ('mala', 39), ('relógio', 40), ('campera', 41), ('bebe', 42), ('original', 43), ('fogão', 44), ('bacha', 45), ('220v', 46), ('vinho', 47), ('cartão', 48), ('industrial', 49), ('reloj', 50), ('s', 51), ('sandisk', 52), ('6', 53), ('preto', 54), ('bermuda', 55), ('memoria', 56), ('valija', 57), ('bocas', 58), ('talle', 59), ('johnson', 60), ('impacto', 61), ('butaca', 62), ('cuba', 63), ('viagem', 64), ('cm', 65), ('acero', 66), ('em', 67), ('0', 68), ('malbec', 69), ('black', 70), ('colchon', 71), ('coser', 72), ('8', 73), ('grande', 74), ('costura', 75), ('yamaha', 76), ('110v', 77), ('casio', 78), ('pared', 79), ('azul', 80), ('en', 81), ('p', 82), ('huevito', 83), ('vino', 84), ('moto', 85), ('masculina', 86), ('wahl', 87), ('preta', 88), ('mini', 89), ('pileta', 90), ('feminina', 91), ('conforto', 92), ('cochecito', 93), ('geladeira', 94), ('m', 95), ('jean', 96), ('infantil', 97), ('kg', 98), ('roller', 99), ('pelo', 100), ('pro', 101), ('estado', 102), ('36', 103), ('frost', 104), ('branco', 105), ('32gb', 106), ('percutor', 107), ('teclas', 108), ('rosa', 109), ('rodas', 110), ('litros', 111), ('cabelo', 112), ('espuma', 113), ('cadeira', 114), ('marca', 115), ('memória', 116), ('colchón', 117), ('ultra', 118), ('singer', 119), ('plus', 120), ('750ml', 121), ('9', 122), ('alta', 123), ('ruedas', 124), ('frete', 125), ('no', 126), ('base', 127), ('tramontina', 128), ('patines', 129), ('gratis', 130), ('filhotes', 131), ('oferta', 132), ('modelo', 133), ('rollers', 134), ('negro', 135), ('61', 136), ('carro', 137), ('corte', 138), ('pantalon', 139), ('clase', 140), ('cortar', 141), ('casal', 142), ('12', 143), ('mujer', 144), ('127v', 145), ('super', 146), ('combo', 147), ('coche', 148), ('uso', 149), ('electrolux', 150), ('envio', 151), ('64gb', 152), ('tam', 153), ('doble', 154), ('cinza', 155), ('sin', 156), ('bivolt', 157), ('30', 158), ('griferia', 159), ('baby', 160), ('solteiro', 161), ('cuotas', 162), ('vendo', 163), ('cadeirinha', 164), ('15', 165), ('aço', 166), ('hombre', 167), ('gb', 168), ('conjunto', 169), ('psr', 170), ('profissional', 171), ('shorts', 172), ('freezer', 173), ('semi', 174), ('promoção', 175), ('barba', 176), ('16gb', 177), ('alpinestars', 178), ('kingston', 179), ('la', 180), ('excelente', 181), ('usada', 182), ('100', 183), ('classe', 184), ('sdhc', 185), ('top', 186), ('tinto', 187), ('korg', 188), ('macho', 189), ('booster', 190), ('38', 191), ('cortadora', 192), ('tamanho', 193), ('l', 194), ('cabernet', 195), ('inoxidable', 196), ('free', 197), ('texx', 198), ('t', 199), ('g', 200), ('decker', 201), ('13mm', 202), ('nueva', 203), ('café', 204), ('roland', 205), ('chicco', 206), ('nuevo', 207), ('overlock', 208), ('bermudas', 209), ('34', 210), ('brinde', 211), ('refrigerador', 212), ('vintage', 213), ('king', 214), ('filhote', 215), ('luxor', 216), ('brastemp', 217), ('nespresso', 218), ('32', 219), ('20', 220), ('18', 221), ('7', 222), ('sem', 223), ('novo', 224), ('profesional', 225), ('alto', 226), ('samsung', 227), ('40', 228), ('bosch', 229), ('molas', 230), ('abs', 231), ('sdxc', 232), ('impecable', 233), ('hornallas', 234), ('750', 235), ('grátis', 236), ('infanti', 237), ('digital', 238), ('ctk', 239), ('adaptador', 240), ('cachorros', 241), ('13', 242), ('usado', 243), ('o', 244), ('vermelho', 245), ('cozinha', 246), ('elétrica', 247), ('bulldog', 248), ('size', 249), ('aparador', 250), ('graco', 251), ('nova', 252), ('25', 253), ('ml', 254), ...

# %% [markdown]
# Con la función prepare_tokenizer , recibe el dataframe y retorna una lista de pabras con la más frecuente.

# %%
def prepare_tokenizer(words):
    '''
        funcion que genera un vocabulario, toma una lista de palabras.
        retorna una lista de palabras tokenizadas.
    '''
    # obtain a tokenizer
    t = Tokenizer(filters = '-.+,[@_!#$%^&*()<>?/\|}{~:]0123456789', lower=True) # filters and lower
    t.fit_on_texts(words) #Actualiza el vocabulario interno basado en una lista de textos.
    dictionary = dict(); rev_dictionary = dict()#definimos diccionarios
    #recorremos todos los elementos, palabra por palabra.
    for key, value in t.word_index.items():
        dictionary[value] = key
        rev_dictionary[key] = value
    #tamaño del diccionario de frecuencias.
    vocab_size = len(t.word_index) + 1

    ''' Small modification from Animesh
        # also add the '<unk>' token to the dictionary at 0th position
    '''
    dictionary[0] = '<unk>'; rev_dictionary['<unk>'] = 0

    #print (vocab_size) # size vocab
	# integer encode the documents
    encoded_docs = t.texts_to_sequences(words)

    return (dictionary, rev_dictionary, vocab_size)

# %%
prepare_tokenizer(df.title)
# Out:
# ({1: 'de',
#   2: 'x',
#   3: 'para',
#   4: 'v',
#   5: 'a',
#   6: 'gb',
#   7: 'com',
#   8: 'cocina',
#   9: 'con',
#   10: 'cm',
#   11: 'e',
#   12: 'kit',
#   13: 'teclado',
#   14: 'c',
#   15: 'maquina',
#   16: 'w',
#   17: 'y',
#   18: 'máquina',
#   19: 'micro',
#   20: 's',
#   21: 'sd',
#   22: 'inox',
#   23: 'heladera',
#   24: 'jaqueta',
#   25: 'colchão',
#   26: 'patins',
#   27: 'carrinho',
#   28: 'calça',
#   29: 'bebê',
#   30: 'cafetera',
#   31: 'kg',
#   32: 'jeans',
#   33: 'taladro',
#   34: 'furadeira',
#   35: 'auto',
#   36: 'short',
#   37: 'cafeteira',
#   38: 'parede',
#   39: 'mala',
#   40: 'relógio',
#   41: 'campera',
#   42: 'bebe',
#   43: 'original',
#   44: 'fogão',
#   45: 'bacha',
#   46: 'vinho',
#   47: 'cartão',
#   48: 'industrial',
#   49: 'd',
#   50: 'reloj',
#   51: 'sandisk',
#   52: 'ml',
#   53: 'preto',
#   54: 'm',
#   55: 'mm',
#   56: 'bermuda',
#   57: 'memoria',
#   58: 'valija',
#   59: 'bocas',
#   60: 'talle',
#   61: 'l',
#   62: 'johnson',
#   63: 'impacto',
#   64: 'butaca',
#   65: 'cuba',
#   66: 'p',
#   67: 'viagem',
#   68: 'acero',
#   69: 'em',
#   70: 'malbec',
#   71: 'black',
#   72: 'colchon',
#   73: 'coser',
#   74: 'grande',
#   75: 'costura',
#   76: 'yamaha',
#   77: 'en',
#   78: 'casio',
#   79: 'mb',
#   80: 'pared',
#   81: 'azul',
#   82: 'huevito',
#   83: 'vino',
#   84: 'g',
#   85: 'moto',
#   86: 'masculina',
#   87: 'wahl',
#   88: 'mini',
#   89: 'preta',
#   90: 'pileta',
#   91: 'feminina',
#   92: 'conforto',
#   93: 'cochecito',
#   94: 'geladeira',
#   95: 'jean',
#   96: 'infantil',
#   97: 'roller',
#   98: 'pro',
#   99: 'pelo',
#   100: 'estado',
#   101: 'frost',
#   102: 'branco',
#   103: 'k',
#   104: 'teclas',
#   105: 'percutor',
#   106: 'litros',
#   107: 'rodas',
#   108: 'rosa',
#   109: 'cabelo',
#   110: 'espuma',
#   111: 'cadeira',
#   112: 'marca',
#   113: 'memória',
#   114: 'ultra',
#   115: 'colchón',
#   116: 'singer',
#   117: 'plus',
#   118: 'alta',
#   119: 'b',
#   120: 'ruedas',
#   121: 't',
#   122: 'frete',
#   123: 'no',
#   124: 'base',
#   125: 'tramontina',
#   126: 'patines',
#   127: 'gratis',
#   128: 'clase',
#   129: 'filhotes',
#   130: 'oferta',
#   131: 'modelo',
#   132: 'rollers',
#   133: 'negro',
#   134: 'carro',
#   135: 'corte',
#   136: 'pantalon',
#   137: 'cortar',
#   138: 'casal',
#   139: 'mujer',
#   140: 'combo',
#   141: 'super',
#   142: 'coche',
#   143: 'uso',
#   144: 'ctk',
#   145: 'envio',
#   146: 'tam',
#   147: 'electrolux',
#   148: 'doble',
#   149: 'cinza',
#   150: 'sin',
#   151: 'bivolt',
#   152: 'cuotas',
#   153: 'griferia',
#   154: 'classe',
#   155: 'psr',
#   156: 'baby',
#   157: 'solteiro',
#   158: 'vendo',
#   159: 'cadeirinha',
#   160: 'aço',
#   161: 'hombre',
#   162: 'conjunto',
#   163: 'profissional',
#   164: 'shorts',
#   165: 'freezer',
#   166: 'semi',
#   167: 'si',
#   168: 'barba',
#   169: 'promoção',
#   170: 'alpinestars',
#   171: 'kingston',
#   172: 'la',
#   173: 'excelente',
#   174: 'usada',
#   175: 'top',
#   176: 'sdhc',
#   177: 'tinto',
#   178: 'macho',
#   179: 'korg',
#   180: 'booster',
#   181: 'tamanho',
#   182: 'cortadora',
#   183: 'xl',
#   184: 'cabernet',
#   185: 'inoxidable',
#   186: 'free',
#   187: 'texx',
#   188: 'decker',
#   189: 'nueva',
#   190: 'café',
#   191: 'roland',
#   192: 'chicco',
#   193: 'nuevo',
#   194: 'overlock',
#   195: 'bermudas',
#   196: 'r',
#   197: 'brinde',
#   198: 'refrigerador',
#   199: 'vintage',
#   200: 'king',
#   201: 'filhote',
#   202: 'luxor',
#   203: 'acc',
#   204: 'brastemp',
#   205: 'nespresso',
#   206: 'lts',
#   207: 'sem',
#   208: 'novo',
#   209: 'profesional',
#   210: 'cjn',
#   211: 'o',
#   212: 'samsung',
#   213: 'alto',
#   214: 'bosch',
#   215: 'molas',
#   216: 'hornallas',
#   217: 'abs',
#   218: 'sdxc',
#   219: 'impecable',
#   220: 'grátis',
#   221: 'infanti',
#   222: 'digital',
#   223: 'size',
#   224: 'adaptador',
#   225: 'cachorros',
#   226: 'usado',
#   227: 'vermelho',
#   228: 'cozinha',
#   229: 'graco',
#   230: 'elétrica',
#   231: 'bulldog',
#   232: 'aparador',
#   233: 'nova',
#   234: 'vermelha',
#   235: 'blanca',
#   236: 'malas',
#   237: 'queen',
#   238: 'pia',
#   239: 'silla',
#   240: 'f',
#   241: 'burigotto',
#   242: 'set',
#   243: 'impermeável',
#   244: 'couro',
#   245: 'da',
#   246: 'corta',
#   247: 'travel',
#   248: 'n',
#   249: 'el',
#   250: 'pantalón',
#   251: 'dolce',
#   252: 'gas',
#   253: 'u',
#   254: 'plaza',
#   255: 'feminino',
#   256: 'gama',
#   257: 'philips',
#   258: 'gusto',
#   259: 'negra',
#   260: 'moletom',
#   261: 'forno',
#   262: 'expresso',
#   263: 'caja',
#   264: 'garantia',
#   265: 'q',
#   266: 'sintetizador',
#   267: 'tarjeta',
#   268: 'do',
#   269: 'reserva',
#   270: 'consul',
#   271: 'love',
#   272: 'extreme',
#   273: 'express',
#   274: 'del',
#   275: 'one',
#   276: 'entrega',
#   277: 'galzerano',
#   278: 'hd',
#   279: 'italiana',
#   280: 'cintura',
#   281: 'bordo',
#   282: 'cannon',
#   283: 'h',
#   284: 'in',
#   285: 'skinny',
#   286: 'resortes',
#   287: 'frigobar',
#   288: 'mediana',
#   289: 'bebé',
#   290: 'simple',
#   291: 'new',
#   292: 'valijas',
#   293: 'verde',
#   294: 'premium',
#   295: 'cuero',
#   296: 'i',
#   297: 'sauvignon',
#   298: 'al',
#   299: 'system',
#   300: 'plazas',
#   301: 'unidades',
#   302: 'color',
#   303: 'sensitivo',
#   304: 'atacado',
#   305: 'philco',
#   306: 'ao',
#   307: 'piano',
#   308: 'muy',
#   309: 'portátil',
#   310: 'relogio',
#   311: 'passeio',
#   312: 'lycra',
#   313: 'janome',
#   314: 'blanco',
#   315: 'ls',
#   316: 're',
#   317: 'motor',
#   318: 'pelos',
#   319: 'mi',
#   320: 'pequena',
#   321: 'hilos',
#   322: 'pocket',
#   323: 'samsonite',
#   324: 'abec',
#   325: 'xícaras',
#   326: 'oster',
#   327: 'branca',
#   328: 'dewalt',
#   329: 'calças',
#   330: 'peças',
#   331: 'gris',
#   332: 'cartao',
#   333: 'niño',
#   334: 'ortobom',
#   335: 'led',
#   336: 'patrick',
#   337: 'regalo',
#   338: 'line',
#   339: 'organo',
#   340: 'pillow',
#   341: 'hc',
#   342: 'rígida',
#   343: 'andis',
#   344: 'chupin',
#   345: 'evo',
#   346: 'makita',
#   347: 'filtro',
#   348: 'buen',
#   349: 'rodinhas',
#   350: 'disco',
#   351: 'densidad',
#   352: 'cc',
#   353: 'mesa',
#   354: 'pedigree',
#   355: 'gsb',
#   356: 'porta',
#   357: 'red',
#   358: 'recta',
#   359: 'por',
#   360: 'quad',
#   361: 'º',
#   362: 'slim',
#   363: 'gás',
#   364: 'retro',
#   365: 'uhs',
#   366: 'accesorios',
#   367: 'extensibles',
#   368: 'niños',
#   369: 'meses',
#   370: 'masculino',
#   371: 'redondo',
#   372: 'cuna',
#   373: 'by',
#   374: 'whirlpool',
#   375: 'traxart',
#   376: 'acabamento',
#   377: 'trimmer',
#   378: 'pronta',
#   379: 'elastizado',
#   380: 'arranjador',
#   381: 'rigida',
#   382: 'fêmea',
#   383: 'usb',
#   384: 'maleta',
#   385: 'max',
#   386: 'ajustável',
#   387: 'electrica',
#   388: 'air',
#   389: 'luna',
#   390: 'como',
#   391: 'microsd',
#   392: 'cargo',
#   393: 'octavas',
#   394: 'cabina',
#   395: 'star',
#   396: 'moda',
#   397: 'gran',
#   398: 'tipo',
#   399: 'mod',
#   400: 'cabello',
#   401: 'primicia',
#   402: 'vinil',
#   403: 'importado',
#   404: 'isofix',
#   405: 'média',
#   406: 'gamma',
#   407: 'assento',
#   408: 'reta',
#   409: 'envios',
#   410: 'motoqueiro',
#   411: 'card',
#   412: 'bull',
#   413: 'fuente',
#   414: 'ref',
#   415: 'casa',
#   416: '°',
#   417: 'motociclista',
#   418: 'oficial',
#   419: 'piero',
#   420: 'horno',
#   421: 'aluminio',
#   422: 'frances',
#   423: 'cervejeira',
#   424: 'sarja',
#   425: 'pressão',
#   426: 'un',
#   427: 'cachorro',
#   428: 'acessórios',
#   429: 'memory',
#   430: 'jogger',
#   431: 'cortador',
#   432: 'patin',
#   433: 'magnético',
#   434: 'kiddy',
#   435: 'cordura',
#   436: 'bolso',
#   437: 'gafa',
#   438: 'side',
#   439: 'protecciones',
#   440: 'bajo',
#   441: 'class',
#   442: 'maxi',
#   443: 'blue',
#   444: 'años',
#   445: 'dupla',
#   446: 'disney',
#   447: 'tiro',
#   448: 'mesada',
#   449: 'argentino',
#   450: 'quadra',
#   451: 'nariz',
#   452: 'mondial',
#   453: 'alemão',
#   454: 'peg',
#   455: 'rojo',
#   456: 'moulinex',
#   457: 'perego',
#   458: 'luz',
#   459: 'tactel',
#   460: 'nena',
#   461: 'sp',
#   462: 'bb',
#   463: 'até',
#   464: 'cor',
#   465: 'vidro',
#   466: 'morelli',
#   467: 'machos',
#   468: 'funcionando',
#   469: 'usa',
#   470: 'fogao',
#   471: 'musical',
#   472: 'hembra',
#   473: 'madera',
#   474: 'evolution',
#   475: 'lindos',
#   476: 'poco',
#   477: 'gc',
#   478: 'kiddo',
#   479: 'solo',
#   480: 'american',
#   481: 'hp',
#   482: 'blend',
#   483: 'fca',
#   484: 'bolsa',
#   485: 'ii',
#   486: 'espresso',
#   487: 'fonte',
#   488: 'magic',
#   489: 'skil',
#   490: 'stanley',
#   491: 'completo',
#   492: 'se',
#   493: 'estilo',
#   494: 'envío',
#   495: 'clássico',
#   496: 'funda',
#   497: 'lacrado',
#   498: 'ca',
#   499: 'adidas',
#   500: 'tradicional',
#   501: 'retrô',
#   502: 'metal',
#   503: 'strike',
#   504: 'inline',
#   505: 'multigas',
#   506: 'lote',
#   507: 'proteção',
#   508: 'los',
#   509: 'reversível',
#   510: 'caixa',
#   511: 'brother',
#   512: 'ou',
#   513: 'gn',
#   514: 'embutir',
#   515: 'soporte',
#   516: 'viaje',
#   517: 'terrier',
#   518: 'j',
#   519: 'importada',
#   520: 'multikids',
#   521: 'atma',
#   522: 'toy',
#   523: 'na',
#   524: 'ma',
#   525: 'suavestar',
#   526: 'decoração',
#   527: 'tanque',
#   528: 'à',
#   529: 'vidrio',
#   530: 'fio',
#   531: 'clipper',
#   532: 'nf',
#   533: 'catena',
#   534: 'dias',
#   535: 'sport',
#   536: 'talles',
#   537: 'br',
#   538: 'flare',
#   539: 'hasta',
#   540: 'nº',
#   541: 'barato',
#   542: 'decorativo',
#   543: 'anos',
#   544: 'plata',
#   545: 'berço',
#   546: 'florencia',
#   547: 'z',
#   548: 'sony',
#   549: 'paseo',
#   550: 'pack',
#   551: 'pit',
#   552: 'válvula',
#   553: 'clip',
#   554: 'reclinável',
#   555: 'patillera',
#   556: 'paraguitas',
#   557: 'fit',
#   558: 'spitz',
#   559: 'bebesit',
#   560: 'linda',
#   561: 'bar',
#   562: 'cadence',
#   563: 'duplex',
#   564: 'motos',
#   565: 'zona',
#   566: 'dos',
#   567: 'prata',
#   568: 'light',
#   569: 'on',
#   570: 'classic',
#   571: 'venax',
#   572: 'saeco',
#   573: 'automático',
#   574: 'pa',
#   575: 'rodinha',
#   576: 'gabardina',
#   577: 'tampa',
#   578: 'pug',
#   579: 'yorkshire',
#   580: 'design',
#   581: 'style',
#   582: 'pocillos',
#   583: 'rollerblade',
#   584: 'recargable',
#   585: 'perfecto',
#   586: 'pitbull',
#   587: 'caniche',
#   588: 'completa',
#   589: 'cordless',
#   590: 'bebes',
#   591: 'lujo',
#   592: 'maletin',
#   593: 'nike',
#   594: 'relojes',
#   595: 'chica',
#   596: 'hot',
#   597: 'jack',
#   598: 'pedal',
#   599: 'flash',
#   600: 'piezas',
#   601: 'profesionales',
#   602: 'funciona',
#   603: 'soy',
#   604: 'cs',
#   605: 'ar',
#   606: 'cadeado',
#   607: 'motorman',
#   608: 'luxo',
#   609: 'ideal',
#   610: 'lançamento',
#   611: 'tazas',
#   612: 'volts',
#   613: 'madeira',
#   614: 'seco',
#   615: 'academia',
#   616: 'galoneira',
#   617: 'media',
#   618: 'rs',
#   619: 'baixa',
#   620: 'paraguita',
#   621: 'siruba',
#   622: 'automática',
#   623: 'fila',
#   624: 'femea',
#   625: 'bege',
#   626: 'alumínio',
#   627: 'las',
#   628: 'tutti',
#   629: 'suporte',
#   630: 'eléctrica',
#   631: 'fisher',
#   632: 'resistente',
#   633: 'white',
#   634: 'box',
#   635: 'harley',
#   636: 'me',
#   637: 'acendimento',
#   638: 'manual',
#   639: 'amoladora',
#   640: 'gp',
#   641: 'delsey',
#   642: 'natural',
#   643: 'capa',
#   644: 'portas',
#   645: 'ensacadas',
#   646: 'chardonnay',
#   647: 'extra',
#   648: 'guarda',
#   649: 'racing',
#   650: 'tzu',
#   651: 'escorial',
#   652: 'cafe',
#   653: 'cores',
#   654: 'touring',
#   655: 'galaxy',
#   656: 'full',
#   657: 'safety',
#   658: 'inalambrico',
#   659: 'rock',
#   660: 'rpm',
#   661: 'cx',
#   662: 'cápsulas',
#   663: 'street',
#   664: 'chapa',
#   665: 'impermeable',
#   666: 'brilho',
#   667: 'retangular',
#   668: 'quinny',
#   669: 'longvie',
#   670: 'vinilo',
#   671: 'herweg',
#   672: 'grill',
#   673: 'jogging',
#   674: 'lindo',
#   675: 'praia',
#   676: 'skate',
#   677: 'lg',
#   678: 'master',
#   679: 'especial',
#   680: 'bodega',
#   681: 'mão',
#   682: 'san',
#   683: 'jarra',
#   684: 'piso',
#   685: 'bota',
#   686: 'giro',
#   687: 'shih',
#   688: 'portatil',
#   689: 'posiciones',
#   690: 'duplo',
#   691: 'pastor',
#   692: 'compact',
#   693: 'menina',
#   694: 'fibra',
#   695: 'collareta',
#   696: 'lt',
#   697: 'detailer',
#   698: 'linea',
#   699: 'li',
#   700: 'franke',
#   701: 'maquinas',
#   702: 'mbs',
#   703: 'jogo',
#   704: 'watts',
#   705: 'dwd',
#   706: 'cosi',
#   707: 'verão',
#   708: 'babyliss',
#   709: 'pontos',
#   710: 'massageador',
#   711: 'urban',
#   712: 'arno',
#   713: 'antigua',
#   714: 'celular',
#   715: 'revenda',
#   716: 'plancha',
#   717: 'summer',
#   718: 'lexar',
#   719: 'tutto',
#   720: 'roja',
#   721: 'gold',
#   722: 'extensible',
#   723: 'carry',
#   724: 'preço',
#   725: 'kemei',
#   726: 'ps',
#   727: 'tsa',
#   728: 'sobrepor',
#   729: 'timer',
#   730: 'dama',
#   731: 'atlas',
#   732: 'linha',
#   733: 'fitness',
#   734: 'cmx',
#   735: 'diseño',
#   736: 'redonda',
#   737: 'davidson',
#   738: 'rocket',
#   739: 'visor',
#   740: 'special',
#   741: 'st',
#   742: 'promo',
#   743: 'peabody',
#   744: 'mola',
#   745: 'delonghi',
#   746: 'alça',
#   747: 'dc',
#   748: 'to',
#   749: 'confort',
#   750: 'prime',
#   751: 'francês',
#   752: 'home',
#   753: 'oportunidad',
#   754: 'gg',
#   755: 'hembras',
#   756: 'price',
#   757: 'joe',
#   758: 'inissia',
#   759: 'pol',
#   760: 'colores',
#   761: 'df',
#   762: 'overloque',
#   763: 'garantía',
#   764: 'lady',
#   765: 'panasonic',
#   766: 'mas',
#   767: 'castor',
#   768: 'puerta',
#   769: 'golden',
#   770: 'calidad',
#   771: 'suave',
#   772: 'ac',
#   773: 'taper',
#   774: 'mano',
#   775: 'francesa',
#   776: 'estampada',
#   777: 'todo',
#   778: 'merlot',
#   779: 'elgin',
#   780: 'hgf',
#   781: 'impermeavel',
#   782: 'cosco',
#   783: 'carrito',
#   784: 'acetinado',
#   785: 'n°',
#   786: 'aco',
#   787: 'marrom',
#   788: 'ct',
#   789: 'honda',
#   790: 'menino',
#   791: 'finca',
#   792: 'moderno',
#   793: 'automatica',
#   794: 'multilaser',
#   795: 'domec',
#   796: 'bel',
#   797: 'lulu',
#   798: 'bordado',
#   799: 'antiguo',
#   800: 'mueller',
#   801: 'fox',
#   802: 'basic',
#   803: 'chow',
#   804: 'chuva',
#   805: 'nota',
#   806: 'zara',
#   807: 'mandril',
#   808: 'gourmet',
#   809: 'bialetti',
#   810: 'tropical',
#   811: 'verano',
#   812: 'hogar',
#   813: 'respaldo',
#   814: 'joie',
#   815: 'typical',
#   816: 'revit',
#   817: 'asiento',
#   818: 'cut',
#   819: 'mdf',
#   820: 'pulgadas',
#   821: 'juros',
#   822: 'pantalones',
#   823: 'eletrolux',
#   824: 'caniches',
#   825: 'elastano',
#   826: 'tm',
#   827: 'fix',
#   828: 'caba',
#   829: 'silver',
#   830: 'siam',
#   831: 'pie',
#   832: 'orbis',
#   833: 'boca',
#   834: 'face',
#   835: 'pants',
#   836: 'grafite',
#   837: 'sillita',
#   838: 'grandes',
#   839: 'estuche',
#   840: 'dw',
#   841: 'ce',
#   842: 'all',
#   843: 'duo',
#   844: 'estampado',
#   845: 'cafés',
#   846: 'britax',
#   847: 'francés',
#   848: 'ferrari',
#   849: 'elétrico',
#   850: 'pink',
#   851: 'and',
#   852: 'gm',
#   853: 'envíos',
#   854: 'rl',
#   855: 'glass',
#   856: 'bag',
#   857: 'interes',
#   858: 'einhell',
#   859: 'algodon',
#   860: 'sun',
#   861: 'esmaltec',
#   862: 'remington',
#   863: 'liquido',
#   864: 'matrix',
#   865: 'smart',
#   866: 'workstation',
#   867: 'cf',
#   868: 'chihuahua',
#   869: 'familiar',
#   870: 'brocas',
#   871: 'fv',
#   872: 'camuflada',
#   873: 'bateria',
#   874: 'drive',
#   875: 'fênix',
#   876: 'rutini',
#   877: 'originales',
#   878: 'rt',
#   879: 'zapata',
#   880: 'mc',
#   881: 'go',
#   882: 'pinot',
#   883: 'primo',
#   884: 'vel',
#   885: 'casi',
#   886: 'dainese',
#   887: 'electrico',
#   888: 'at',
#   889: 'eléctrico',
#   890: 'nine',
#   891: 'moka',
#   892: 'polo',
#   893: 'precio',
#   894: 'babucha',
#   895: 'elevação',
#   896: 'yamata',
#   897: 'sports',
#   898: 'legging',
#   899: 'the',
#   900: 'silencioso',
#   901: 'abc',
#   902: 'bumbum',
#   903: 'liviano',
#   904: 'mega',
#   905: 'tecido',
#   906: 'bl',
#   907: 'adulto',
#   908: 'medeli',
#   909: 'social',
#   910: 'franc',
#   911: 'columbia',
#   912: 'bk',
#   913: 'mayor',
#   914: 'touch',
#   915: 'essenza',
#   916: 'microsdhc',
#   917: 'real',
#   918: 'cortapelo',
#   919: 'doméstica',
#   920: 'levis',
#   921: 'descalcificante',
#   922: 'stella',
#   923: 'hpk',
#   924: 'le',
#   925: 'up',
#   926: 'softshell',
#   927: 'di',
#   928: 'powerslide',
#   929: 'city',
#   930: 'ariston',
#   931: 'professional',
#   932: 'art',
#   933: 'shitzu',
#   934: 'santino',
#   935: 'mickey',
#   936: 'congelador',
#   937: 'mais',
#   938: 'colchao',
#   939: 'single',
#   940: 'blanc',
#   941: 'prensa',
#   942: 'local',
#   943: 'dia',
#   944: 'tb',
#   945: 'venâncio',
#   946: 'noir',
#   947: 'liviana',
#   948: 'corações',
#   949: 'rasgada',
#   950: 'hero',
#   951: 'artistico',
#   952: 'nuevos',
#   953: 'aeroccino',
#   954: 'tres',
#   955: 'shaver',
#   956: 'polido',
#   957: 'tapa',
#   958: 'cybex',
#   959: 'dv',
#   960: 'palermo',
#   961: 'amarelo',
#   962: 'moises',
#   963: "''",
#   964: 'cabelos',
#   965: 'chaqueta',
#   966: 'variable',
#   967: 'cubas',
#   968: 'ótimo',
#   969: 'sleep',
#   970: 'cochesito',
#   971: 'mk',
#   972: 'flores',
#   973: 'varios',
#   974: 'vestir',
#   975: 'exclusive',
#   976: 'gopro',
#   977: 'moleton',
#   978: 'sa',
#   979: 'britânia',
#   980: 'diy',
#   981: 'tech',
#   982: 'moisés',
#   983: 'um',
#   984: 'sala',
#   985: 'oxford',
#   986: 'dosificador',
#   987: 'vinhos',
#   988: 'qualidade',
#   989: 'legend',
#   990: 'hydros',
#   991: 'pv',
#   992: 'wk',
#   993: 'ph',
#   994: 'modelos',
#   995: 'dx',
#   996: 'midi',
#   997: 'torneira',
#   998: 'afeitadora',
#   999: 'cd',
#   1000: 'altura',
#   ...},
#  {'de': 1,
#   'x': 2,
#   'para': 3,
#   'v': 4,
#   'a': 5,
#   'gb': 6,
#   'com': 7,
#   'cocina': 8,
#   'con': 9,
#   'cm': 10,
#   'e': 11,
#   'kit': 12,
#   'teclado': 13,
#   'c': 14,
#   'maquina': 15,
#   'w': 16,
#   'y': 17,
#   'máquina': 18,
#   'micro': 19,
#   's': 20,
#   'sd': 21,
#   'inox': 22,
#   'heladera': 23,
#   'jaqueta': 24,
#   'colchão': 25,
#   'patins': 26,
#   'carrinho': 27,
#   'calça': 28,
#   'bebê': 29,
#   'cafetera': 30,
#   'kg': 31,
#   'jeans': 32,
#   'taladro': 33,
#   'furadeira': 34,
#   'auto': 35,
#   'short': 36,
#   'cafeteira': 37,
#   'parede': 38,
#   'mala': 39,
#   'relógio': 40,
#   'campera': 41,
#   'bebe': 42,
#   'original': 43,
#   'fogão': 44,
#   'bacha': 45,
#   'vinho': 46,
#   'cartão': 47,
#   'industrial': 48,
#   'd': 49,
#   'reloj': 50,
#   'sandisk': 51,
#   'ml': 52,
#   'preto': 53,
#   'm': 54,
#   'mm': 55,
#   'bermuda': 56,
#   'memoria': 57,
#   'valija': 58,
#   'bocas': 59,
#   'talle': 60,
#   'l': 61,
#   'johnson': 62,
#   'impacto': 63,
#   'butaca': 64,
#   'cuba': 65,
#   'p': 66,
#   'viagem': 67,
#   'acero': 68,
#   'em': 69,
#   'malbec': 70,
#   'black': 71,
#   'colchon': 72,
#   'coser': 73,
#   'grande': 74,
#   'costura': 75,
#   'yamaha': 76,
#   'en': 77,
#   'casio': 78,
#   'mb': 79,
#   'pared': 80,
#   'azul': 81,
#   'huevito': 82,
#   'vino': 83,
#   'g': 84,
#   'moto': 85,
#   'masculina': 86,
#   'wahl': 87,
#   'mini': 88,
#   'preta': 89,
#   'pileta': 90,
#   'feminina': 91,
#   'conforto': 92,
#   'cochecito': 93,
#   'geladeira': 94,
#   'jean': 95,
#   'infantil': 96,
#   'roller': 97,
#   'pro': 98,
#   'pelo': 99,
#   'estado': 100,
#   'frost': 101,
#   'branco': 102,
#   'k': 103,
#   'teclas': 104,
#   'percutor': 105,
#   'litros': 106,
#   'rodas': 107,
#   'rosa': 108,
#   'cabelo': 109,
#   'espuma': 110,
#   'cadeira': 111,
#   'marca': 112,
#   'memória': 113,
#   'ultra': 114,
#   'colchón': 115,
#   'singer': 116,
#   'plus': 117,
#   'alta': 118,
#   'b': 119,
#   'ruedas': 120,
#   't': 121,
#   'frete': 122,
#   'no': 123,
#   'base': 124,
#   'tramontina': 125,
#   'patines': 126,
#   'gratis': 127,
#   'clase': 128,
#   'filhotes': 129,
#   'oferta': 130,
#   'modelo': 131,
#   'rollers': 132,
#   'negro': 133,
#   'carro': 134,
#   'corte': 135,
#   'pantalon': 136,
#   'cortar': 137,
#   'casal': 138,
#   'mujer': 139,
#   'combo': 140,
#   'super': 141,
#   'coche': 142,
#   'uso': 143,
#   'ctk': 144,
#   'envio': 145,
#   'tam': 146,
#   'electrolux': 147,
#   'doble': 148,
#   'cinza': 149,
#   'sin': 150,
#   'bivolt': 151,
#   'cuotas': 152,
#   'griferia': 153,
#   'classe': 154,
#   'psr': 155,
#   'baby': 156,
#   'solteiro': 157,
#   'vendo': 158,
#   'cadeirinha': 159,
#   'aço': 160,
#   'hombre': 161,
#   'conjunto': 162,
#   'profissional': 163,
#   'shorts': 164,
#   'freezer': 165,
#   'semi': 166,
#   'si': 167,
#   'barba': 168,
#   'promoção': 169,
#   'alpinestars': 170,
#   'kingston': 171,
#   'la': 172,
#   'excelente': 173,
#   'usada': 174,
#   'top': 175,
#   'sdhc': 176,
#   'tinto': 177,
#   'macho': 178,
#   'korg': 179,
#   'booster': 180,
#   'tamanho': 181,
#   'cortadora': 182,
#   'xl': 183,
#   'cabernet': 184,
#   'inoxidable': 185,
#   'free': 186,
#   'texx': 187,
#   'decker': 188,
#   'nueva': 189,
#   'café': 190,
#   'roland': 191,
#   'chicco': 192,
#   'nuevo': 193,
#   'overlock': 194,
#   'bermudas': 195,
#   'r': 196,
#   'brinde': 197,
#   'refrigerador': 198,
#   'vintage': 199,
#   'king': 200,
#   'filhote': 201,
#   'luxor': 202,
#   'acc': 203,
#   'brastemp': 204,
#   'nespresso': 205,
#   'lts': 206,
#   'sem': 207,
#   'novo': 208,
#   'profesional': 209,
#   'cjn': 210,
#   'o': 211,
#   'samsung': 212,
#   'alto': 213,
#   'bosch': 214,
#   'molas': 215,
#   'hornallas': 216,
#   'abs': 217,
#   'sdxc': 218,
#   'impecable': 219,
#   'grátis': 220,
#   'infanti': 221,
#   'digital': 222,
#   'size': 223,
#   'adaptador': 224,
#   'cachorros': 225,
#   'usado': 226,
#   'vermelho': 227,
#   'cozinha': 228,
#   'graco': 229,
#   'elétrica': 230,
#   'bulldog': 231,
#   'aparador': 232,
#   'nova': 233,
#   'vermelha': 234,
#   'blanca': 235,
#   'malas': 236,
#   'queen': 237,
#   'pia': 238,
#   'silla': 239,
#   'f': 240,
#   'burigotto': 241,
#   'set': 242,
#   'impermeável': 243,
#   'couro': 244,
#   'da': 245,
#   'corta': 246,
#   'travel': 247,
#   'n': 248,
#   'el': 249,
#   'pantalón': 250,
#   'dolce': 251,
#   'gas': 252,
#   'u': 253,
#   'plaza': 254,
#   'feminino': 255,
#   'gama': 256,
#   'philips': 257,
#   'gusto': 258,
#   'negra': 259,
#   'moletom': 260,
#   'forno': 261,
#   'expresso': 262,
#   'caja': 263,
#   'garantia': 264,
#   'q': 265,
#   'sintetizador': 266,
#   'tarjeta': 267,
#   'do': 268,
#   'reserva': 269,
#   'consul': 270,
#   'love': 271,
#   'extreme': 272,
#   'express': 273,
#   'del': 274,
#   'one': 275,
#   'entrega': 276,
#   'galzerano': 277,
#   'hd': 278,
#   'italiana': 279,
#   'cintura': 280,
#   'bordo': 281,
#   'cannon': 282,
#   'h': 283,
#   'in': 284,
#   'skinny': 285,
#   'resortes': 286,
#   'frigobar': 287,
#   'mediana': 288,
#   'bebé': 289,
#   'simple': 290,
#   'new': 291,
#   'valijas': 292,
#   'verde': 293,
#   'premium': 294,
#   'cuero': 295,
#   'i': 296,
#   'sauvignon': 297,
#   'al': 298,
#   'system': 299,
#   'plazas': 300,
#   'unidades': 301,
#   'color': 302,
#   'sensitivo': 303,
#   'atacado': 304,
#   'philco': 305,
#   'ao': 306,
#   'piano': 307,
#   'muy': 308,
#   'portátil': 309,
#   'relogio': 310,
#   'passeio': 311,
#   'lycra': 312,
#   'janome': 313,
#   'blanco': 314,
#   'ls': 315,
#   're': 316,
#   'motor': 317,
#   'pelos': 318,
#   'mi': 319,
#   'pequena': 320,
#   'hilos': 321,
#   'pocket': 322,
#   'samsonite': 323,
#   'abec': 324,
#   'xícaras': 325,
#   'oster': 326,
#   'branca': 327,
#   'dewalt': 328,
#   'calças': 329,
#   'peças': 330,
#   'gris': 331,
#   'cartao': 332,
#   'niño': 333,
#   'ortobom': 334,
#   'led': 335,
#   'patrick': 336,
#   'regalo': 337,
#   'line': 338,
#   'organo': 339,
#   'pillow': 340,
#   'hc': 341,
#   'rígida': 342,
#   'andis': 343,
#   'chupin': 344,
#   'evo': 345,
#   'makita': 346,
#   'filtro': 347,
#   'buen': 348,
#   'rodinhas': 349,
#   'disco': 350,
#   'densidad': 351,
#   'cc': 352,
#   'mesa': 353,
#   'pedigree': 354,
#   'gsb': 355,
#   'porta': 356,
#   'red': 357,
#   'recta': 358,
#   'por': 359,
#   'quad': 360,
#   'º': 361,
#   'slim': 362,
#   'gás': 363,
#   'retro': 364,
#   'uhs': 365,
#   'accesorios': 366,
#   'extensibles': 367,
#   'niños': 368,
#   'meses': 369,
#   'masculino': 370,
#   'redondo': 371,
#   'cuna': 372,
#   'by': 373,
#   'whirlpool': 374,
#   'traxart': 375,
#   'acabamento': 376,
#   'trimmer': 377,
#   'pronta': 378,
#   'elastizado': 379,
#   'arranjador': 380,
#   'rigida': 381,
#   'fêmea': 382,
#   'usb': 383,
#   'maleta': 384,
#   'max': 385,
#   'ajustável': 386,
#   'electrica': 387,
#   'air': 388,
#   'luna': 389,
#   'como': 390,
#   'microsd': 391,
#   'cargo': 392,
#   'octavas': 393,
#   'cabina': 394,
#   'star': 395,
#   'moda': 396,
#   'gran': 397,
#   'tipo': 398,
#   'mod': 399,
#   'cabello': 400,
#   'primicia': 401,
#   'vinil': 402,
#   'importado': 403,
#   'isofix': 404,
#   'média': 405,
#   'gamma': 406,
#   'assento': 407,
#   'reta': 408,
#   'envios': 409,
#   'motoqueiro': 410,
#   'card': 411,
#   'bull': 412,
#   'fuente': 413,
#   'ref': 414,
#   'casa': 415,
#   '°': 416,
#   'motociclista': 417,
#   'oficial': 418,
#   'piero': 419,
#   'horno': 420,
#   'aluminio': 421,
#   'frances': 422,
#   'cervejeira': 423,
#   'sarja': 424,
#   'pressão': 425,
#   'un': 426,
#   'cachorro': 427,
#   'acessórios': 428,
#   'memory': 429,
#   'jogger': 430,
#   'cortador': 431,
#   'patin': 432,
#   'magnético': 433,
#   'kiddy': 434,
#   'cordura': 435,
#   'bolso': 436,
#   'gafa': 437,
#   'side': 438,
#   'protecciones': 439,
#   'bajo': 440,
#   'class': 441,
#   'maxi': 442,
#   'blue': 443,
#   'años': 444,
#   'dupla': 445,
#   'disney': 446,
#   'tiro': 447,
#   'mesada': 448,
#   'argentino': 449,
#   'quadra': 450,
#   'nariz': 451,
#   'mondial': 452,
#   'alemão': 453,
#   'peg': 454,
#   'rojo': 455,
#   'moulinex': 456,
#   'perego': 457,
#   'luz': 458,
#   'tactel': 459,
#   'nena': 460,
#   'sp': 461,
#   'bb': 462,
#   'até': 463,
#   'cor': 464,
#   'vidro': 465,
#   'morelli': 466,
#   'machos': 467,
#   'funcionando': 468,
#   'usa': 469,
#   'fogao': 470,
#   'musical': 471,
#   'hembra': 472,
#   'madera': 473,
#   'evolution': 474,
#   'lindos': 475,
#   'poco': 476,
#   'gc': 477,
#   'kiddo': 478,
#   'solo': 479,
#   'american': 480,
#   'hp': 481,
#   'blend': 482,
#   'fca': 483,
#   'bolsa': 484,
#   'ii': 485,
#   'espresso': 486,
#   'fonte': 487,
#   'magic': 488,
#   'skil': 489,
#   'stanley': 490,
#   'completo': 491,
#   'se': 492,
#   'estilo': 493,
#   'envío': 494,
#   'clássico': 495,
#   'funda': 496,
#   'lacrado': 497,
#   'ca': 498,
#   'adidas': 499,
#   'tradicional': 500,
#   'retrô': 501,
#   'metal': 502,
#   'strike': 503,
#   'inline': 504,
#   'multigas': 505,
#   'lote': 506,
#   'proteção': 507,
#   'los': 508,
#   'reversível': 509,
#   'caixa': 510,
#   'brother': 511,
#   'ou': 512,
#   'gn': 513,
#   'embutir': 514,
#   'soporte': 515,
#   'viaje': 516,
#   'terrier': 517,
#   'j': 518,
#   'importada': 519,
#   'multikids': 520,
#   'atma': 521,
#   'toy': 522,
#   'na': 523,
#   'ma': 524,
#   'suavestar': 525,
#   'decoração': 526,
#   'tanque': 527,
#   'à': 528,
#   'vidrio': 529,
#   'fio': 530,
#   'clipper': 531,
#   'nf': 532,
#   'catena': 533,
#   'dias': 534,
#   'sport': 535,
#   'talles': 536,
#   'br': 537,
#   'flare': 538,
#   'hasta': 539,
#   'nº': 540,
#   'barato': 541,
#   'decorativo': 542,
#   'anos': 543,
#   'plata': 544,
#   'berço': 545,
#   'florencia': 546,
#   'z': 547,
#   'sony': 548,
#   'paseo': 549,
#   'pack': 550,
#   'pit': 551,
#   'válvula': 552,
#   'clip': 553,
#   'reclinável': 554,
#   'patillera': 555,
#   'paraguitas': 556,
#   'fit': 557,
#   'spitz': 558,
#   'bebesit': 559,
#   'linda': 560,
#   'bar': 561,
#   'cadence': 562,
#   'duplex': 563,
#   'motos': 564,
#   'zona': 565,
#   'dos': 566,
#   'prata': 567,
#   'light': 568,
#   'on': 569,
#   'classic': 570,
#   'venax': 571,
#   'saeco': 572,
#   'automático': 573,
#   'pa': 574,
#   'rodinha': 575,
#   'gabardina': 576,
#   'tampa': 577,
#   'pug': 578,
#   'yorkshire': 579,
#   'design': 580,
#   'style': 581,
#   'pocillos': 582,
#   'rollerblade': 583,
#   'recargable': 584,
#   'perfecto': 585,
#   'pitbull': 586,
#   'caniche': 587,
#   'completa': 588,
#   'cordless': 589,
#   'bebes': 590,
#   'lujo': 591,
#   'maletin': 592,
#   'nike': 593,
#   'relojes': 594,
#   'chica': 595,
#   'hot': 596,
#   'jack': 597,
#   'pedal': 598,
#   'flash': 599,
#   'piezas': 600,
#   'profesionales': 601,
#   'funciona': 602,
#   'soy': 603,
#   'cs': 604,
#   'ar': 605,
#   'cadeado': 606,
#   'motorman': 607,
#   'luxo': 608,
#   'ideal': 609,
#   'lançamento': 610,
#   'tazas': 611,
#   'volts': 612,
#   'madeira': 613,
#   'seco': 614,
#   'academia': 615,
#   'galoneira': 616,
#   'media': 617,
#   'rs': 618,
#   'baixa': 619,
#   'paraguita': 620,
#   'siruba': 621,
#   'automática': 622,
#   'fila': 623,
#   'femea': 624,
#   'bege': 625,
#   'alumínio': 626,
#   'las': 627,
#   'tutti': 628,
#   'suporte': 629,
#   'eléctrica': 630,
#   'fisher': 631,
#   'resistente': 632,
#   'white': 633,
#   'box': 634,
#   'harley': 635,
#   'me': 636,
#   'acendimento': 637,
#   'manual': 638,
#   'amoladora': 639,
#   'gp': 640,
#   'delsey': 641,
#   'natural': 642,
#   'capa': 643,
#   'portas': 644,
#   'ensacadas': 645,
#   'chardonnay': 646,
#   'extra': 647,
#   'guarda': 648,
#   'racing': 649,
#   'tzu': 650,
#   'escorial': 651,
#   'cafe': 652,
#   'cores': 653,
#   'touring': 654,
#   'galaxy': 655,
#   'full': 656,
#   'safety': 657,
#   'inalambrico': 658,
#   'rock': 659,
#   'rpm': 660,
#   'cx': 661,
#   'cápsulas': 662,
#   'street': 663,
#   'chapa': 664,
#   'impermeable': 665,
#   'brilho': 666,
#   'retangular': 667,
#   'quinny': 668,
#   'longvie': 669,
#   'vinilo': 670,
#   'herweg': 671,
#   'grill': 672,
#   'jogging': 673,
#   'lindo': 674,
#   'praia': 675,
#   'skate': 676,
#   'lg': 677,
#   'master': 678,
#   'especial': 679,
#   'bodega': 680,
#   'mão': 681,
#   'san': 682,
#   'jarra': 683,
#   'piso': 684,
#   'bota': 685,
#   'giro': 686,
#   'shih': 687,
#   'portatil': 688,
#   'posiciones': 689,
#   'duplo': 690,
#   'pastor': 691,
#   'compact': 692,
#   'menina': 693,
#   'fibra': 694,
#   'collareta': 695,
#   'lt': 696,
#   'detailer': 697,
#   'linea': 698,
#   'li': 699,
#   'franke': 700,
#   'maquinas': 701,
#   'mbs': 702,
#   'jogo': 703,
#   'watts': 704,
#   'dwd': 705,
#   'cosi': 706,
#   'verão': 707,
#   'babyliss': 708,
#   'pontos': 709,
#   'massageador': 710,
#   'urban': 711,
#   'arno': 712,
#   'antigua': 713,
#   'celular': 714,
#   'revenda': 715,
#   'plancha': 716,
#   'summer': 717,
#   'lexar': 718,
#   'tutto': 719,
#   'roja': 720,
#   'gold': 721,
#   'extensible': 722,
#   'carry': 723,
#   'preço': 724,
#   'kemei': 725,
#   'ps': 726,
#   'tsa': 727,
#   'sobrepor': 728,
#   'timer': 729,
#   'dama': 730,
#   'atlas': 731,
#   'linha': 732,
#   'fitness': 733,
#   'cmx': 734,
#   'diseño': 735,
#   'redonda': 736,
#   'davidson': 737,
#   'rocket': 738,
#   'visor': 739,
#   'special': 740,
#   'st': 741,
#   'promo': 742,
#   'peabody': 743,
#   'mola': 744,
#   'delonghi': 745,
#   'alça': 746,
#   'dc': 747,
#   'to': 748,
#   'confort': 749,
#   'prime': 750,
#   'francês': 751,
#   'home': 752,
#   'oportunidad': 753,
#   'gg': 754,
#   'hembras': 755,
#   'price': 756,
#   'joe': 757,
#   'inissia': 758,
#   'pol': 759,
#   'colores': 760,
#   'df': 761,
#   'overloque': 762,
#   'garantía': 763,
#   'lady': 764,
#   'panasonic': 765,
#   'mas': 766,
#   'castor': 767,
#   'puerta': 768,
#   'golden': 769,
#   'calidad': 770,
#   'suave': 771,
#   'ac': 772,
#   'taper': 773,
#   'mano': 774,
#   'francesa': 775,
#   'estampada': 776,
#   'todo': 777,
#   'merlot': 778,
#   'elgin': 779,
#   'hgf': 780,
#   'impermeavel': 781,
#   'cosco': 782,
#   'carrito': 783,
#   'acetinado': 784,
#   'n°': 785,
#   'aco': 786,
#   'marrom': 787,
#   'ct': 788,
#   'honda': 789,
#   'menino': 790,
#   'finca': 791,
#   'moderno': 792,
#   'automatica': 793,
#   'multilaser': 794,
#   'domec': 795,
#   'bel': 796,
#   'lulu': 797,
#   'bordado': 798,
#   'antiguo': 799,
#   'mueller': 800,
#   'fox': 801,
#   'basic': 802,
#   'chow': 803,
#   'chuva': 804,
#   'nota': 805,
#   'zara': 806,
#   'mandril': 807,
#   'gourmet': 808,
#   'bialetti': 809,
#   'tropical': 810,
#   'verano': 811,
#   'hogar': 812,
#   'respaldo': 813,
#   'joie': 814,
#   'typical': 815,
#   'revit': 816,
#   'asiento': 817,
#   'cut': 818,
#   'mdf': 819,
#   'pulgadas': 820,
#   'juros': 821,
#   'pantalones': 822,
#   'eletrolux': 823,
#   'caniches': 824,
#   'elastano': 825,
#   'tm': 826,
#   'fix': 827,
#   'caba': 828,
#   'silver': 829,
#   'siam': 830,
#   'pie': 831,
#   'orbis': 832,
#   'boca': 833,
#   'face': 834,
#   'pants': 835,
#   'grafite': 836,
#   'sillita': 837,
#   'grandes': 838,
#   'estuche': 839,
#   'dw': 840,
#   'ce': 841,
#   'all': 842,
#   'duo': 843,
#   'estampado': 844,
#   'cafés': 845,
#   'britax': 846,
#   'francés': 847,
#   'ferrari': 848,
#   'elétrico': 849,
#   'pink': 850,
#   'and': 851,
#   'gm': 852,
#   'envíos': 853,
#   'rl': 854,
#   'glass': 855,
#   'bag': 856,
#   'interes': 857,
#   'einhell': 858,
#   'algodon': 859,
#   'sun': 860,
#   'esmaltec': 861,
#   'remington': 862,
#   'liquido': 863,
#   'matrix': 864,
#   'smart': 865,
#   'workstation': 866,
#   'cf': 867,
#   'chihuahua': 868,
#   'familiar': 869,
#   'brocas': 870,
#   'fv': 871,
#   'camuflada': 872,
#   'bateria': 873,
#   'drive': 874,
#   'fênix': 875,
#   'rutini': 876,
#   'originales': 877,
#   'rt': 878,
#   'zapata': 879,
#   'mc': 880,
#   'go': 881,
#   'pinot': 882,
#   'primo': 883,
#   'vel': 884,
#   'casi': 885,
#   'dainese': 886,
#   'electrico': 887,
#   'at': 888,
#   'eléctrico': 889,
#   'nine': 890,
#   'moka': 891,
#   'polo': 892,
#   'precio': 893,
#   'babucha': 894,
#   'elevação': 895,
#   'yamata': 896,
#   'sports': 897,
#   'legging': 898,
#   'the': 899,
#   'silencioso': 900,
#   'abc': 901,
#   'bumbum': 902,
#   'liviano': 903,
#   'mega': 904,
#   'tecido': 905,
#   'bl': 906,
#   'adulto': 907,
#   'medeli': 908,
#   'social': 909,
#   'franc': 910,
#   'columbia': 911,
#   'bk': 912,
#   'mayor': 913,
#   'touch': 914,
#   'essenza': 915,
#   'microsdhc': 916,
#   'real': 917,
#   'cortapelo': 918,
#   'doméstica': 919,
#   'levis': 920,
#   'descalcificante': 921,
#   'stella': 922,
#   'hpk': 923,
#   'le': 924,
#   'up': 925,
#   'softshell': 926,
#   'di': 927,
#   'powerslide': 928,
#   'city': 929,
#   'ariston': 930,
#   'professional': 931,
#   'art': 932,
#   'shitzu': 933,
#   'santino': 934,
#   'mickey': 935,
#   'congelador': 936,
#   'mais': 937,
#   'colchao': 938,
#   'single': 939,
#   'blanc': 940,
#   'prensa': 941,
#   'local': 942,
#   'dia': 943,
#   'tb': 944,
#   'venâncio': 945,
#   'noir': 946,
#   'liviana': 947,
#   'corações': 948,
#   'rasgada': 949,
#   'hero': 950,
#   'artistico': 951,
#   'nuevos': 952,
#   'aeroccino': 953,
#   'tres': 954,
#   'shaver': 955,
#   'polido': 956,
#   'tapa': 957,
#   'cybex': 958,
#   'dv': 959,
#   'palermo': 960,
#   'amarelo': 961,
#   'moises': 962,
#   "''": 963,
#   'cabelos': 964,
#   'chaqueta': 965,
#   'variable': 966,
#   'cubas': 967,
#   'ótimo': 968,
#   'sleep': 969,
#   'cochesito': 970,
#   'mk': 971,
#   'flores': 972,
#   'varios': 973,
#   'vestir': 974,
#   'exclusive': 975,
#   'gopro': 976,
#   'moleton': 977,
#   'sa': 978,
#   'britânia': 979,
#   'diy': 980,
#   'tech': 981,
#   'moisés': 982,
#   'um': 983,
#   'sala': 984,
#   'oxford': 985,
#   'dosificador': 986,
#   'vinhos': 987,
#   'qualidade': 988,
#   'legend': 989,
#   'hydros': 990,
#   'pv': 991,
#   'wk': 992,
#   'ph': 993,
#   'modelos': 994,
#   'dx': 995,
#   'midi': 996,
#   'torneira': 997,
#   'afeitadora': 998,
#   'cd': 999,
#   'altura': 1000,
#   ...},
#  81155)
